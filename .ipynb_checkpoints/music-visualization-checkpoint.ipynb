# %%
import numpy as np
import pandas as pd
import hypertools as hyp 

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, mean_absolute_error, mean_squared_error
from sklearn.decomposition import FastICA

# %matplotlib inline

# %%
data = pd.read_csv('YearPredictionMSD.csv', header=None)
data.head()
# Out:
#      0         1         2         3         4         5         6         7   \
# 0  2001  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905 -25.01202
# 1  2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777   8.76630
# 2  2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940  -3.27872
# 3  2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683   5.05097
# 4  2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409 -12.48207
#
#          8         9     ...           81         82        83        84  \
# 0 -12.23257   7.83089    ...     13.01620  -54.40548  58.99367  15.37344
# 1  -0.92019  18.76548    ...      5.66812  -19.68073  33.04964  42.87836
# 2  -2.35035  16.07017    ...      3.03800   26.05866 -50.92779  10.93792
# 3 -10.34124   3.55005    ...     34.57337 -171.70734 -16.96705 -46.67617
# 4  -9.37636  12.63699    ...      9.92661  -55.95724  64.92712 -17.72522
#
# ...

# %%
data.columns = ["year"] + ["timb_avg" + str(i) for i in range(12)] + ["timb_cov" + str(i) for i in range(78)]
data.head()
# Out:
#    year  timb_avg0  timb_avg1  timb_avg2  timb_avg3  timb_avg4  timb_avg5  \
# 0  2001   49.94357   21.47114   73.07750    8.74861  -17.40628  -13.09905
# 1  2001   48.73215   18.42930   70.32679   12.94636  -10.32437  -24.83777
# 2  2001   50.95714   31.85602   55.81851   13.41693   -6.57898  -18.54940
# 3  2001   48.24750   -1.89837   36.29772    2.58776    0.97170  -26.21683
# 4  2001   50.97020   42.20998   67.09964    8.46791  -15.85279  -16.81409
#
#    timb_avg6  timb_avg7  timb_avg8     ...      timb_cov68  timb_cov69  \
# 0  -25.01202  -12.23257    7.83089     ...        13.01620   -54.40548
# 1    8.76630   -0.92019   18.76548     ...         5.66812   -19.68073
# 2   -3.27872   -2.35035   16.07017     ...         3.03800    26.05866
# 3    5.05097  -10.34124    3.55005     ...        34.57337  -171.70734
# 4  -12.48207   -9.37636   12.63699     ...         9.92661   -55.95724
#
#    timb_cov70  timb_cov71  timb_cov72  timb_cov73  timb_cov74  timb_cov75  \
# ...

# %%
data = data[data['year'] > 1964]
data = data[data['year'] < 2011]
data.head()

def bootstrap(data, num_to_extract=1000):
    # This function will be applied on each group of instances of the same
    # class in `data`.
    def sampleClass(classgroup):
        cls = classgroup['year'].iloc[0]
        nDesired = num_to_extract
        nRows = len(classgroup)

        nSamples = min(nRows, nDesired)
        return classgroup.sample(nSamples)

    samples = data.groupby('year').apply(sampleClass)
    
    return samples

data = bootstrap(data, 100)

# %%
data.ix[data.year < 1978, 'result'] = 0
data.ix[(data.year > 1977) & (data.year < 1990), 'result'] = 1
data.ix[(data.year > 1989) & (data.year < 2011), 'result'] = 2

labelEncoder = preprocessing.LabelEncoder()
data['result_label'] = labelEncoder.fit_transform(data['result'])

# %%
X = data.drop('year', axis=1)
X = data.drop('result', axis=1)
X = data.drop('result_label', axis=1)
Y = data['year']
Z = data['result']
Z_label = data['result_label']

pca = PCA(n_components=0.99, svd_solver='full')

X = pca.fit_transform(X)
print(X.shape)
# Out:
# (4600, 45)

# %%
TSNE_model = TSNE(n_components=3, verbose=2)
reduced_data_TSNE = TSNE_model.fit_transform(hyp.tools.df2mat(data))
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 1000 / 4600
# [t-SNE] Computed conditional probabilities for sample 2000 / 4600
# [t-SNE] Computed conditional probabilities for sample 3000 / 4600
# [t-SNE] Computed conditional probabilities for sample 4000 / 4600
# [t-SNE] Computed conditional probabilities for sample 4600 / 4600
# [t-SNE] Mean sigma: 336.291424
# [t-SNE] Iteration 25: error = 1.7161237, gradient norm = 0.0062513
# [t-SNE] Iteration 50: error = 1.6834353, gradient norm = 0.0061324
# [t-SNE] Iteration 75: error = 1.5431913, gradient norm = 0.0031863
# [t-SNE] Iteration 100: error = 1.5145202, gradient norm = 0.0040850
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 1.514520
# [t-SNE] Iteration 125: error = 1.4530522, gradient norm = 0.0022334
# [t-SNE] Iteration 150: error = 1.4325067, gradient norm = 0.0031226
# ...

# %%
print (reduced_data_TSNE.shape)
# Out:
# (4600, 3)

# %%
hyp.plot(reduced_data_TSNE,'o', group=Z, legend=list(set(Z)))

# %%
hyp.plot(X,'o', group=Z, legend=list(set(Z)))

# %%
ICA_model = FastICA(n_components=3)
reduced_data_ICA = ICA_model.fit_transform(hyp.tools.df2mat(data))
hyp.plot(reduced_data_ICA,'o', group=Z, legend=list(set(Z)))
